# %% [markdown]
# WORK WITH TERMINAL

# %% [markdown]
# - Source oneAPI environment variables: $source /opt/intel/oneapi/setvars.sh <br>
# - Create conda env: $conda create --name intel-tensorflow --clone tensorflow <br>
# - Activate the created conda env: $source activate intel-tensorflow <br>
# - Install the extra needed package: (intel-tensorflow) $pip install cxxfilt matplotlib ipykernel psutil pandas gitpython <br>
# - Deactivate conda env: (intel-tensorflow)$conda deactivate <br>
# - Register the kernel to Jupyter NB: $~/.conda/envs/intel-tensorflow/bin/python  -m ipykernel install --user --name=intel-tensorflow

# %% [markdown]
# WORK WITH JUPYTER NOTEBOOK

# %%
import os
 
# Get the list of all files and directories
path = "Data"
dir_list = os.listdir(path)

# %%
dir_list
import os
prefixed = [filename for filename in os.listdir('Data') if filename.startswith("CA_")]

# %%
prefixed
# Out:
# ['CA_0672.jpg',
#  'CA_0784.jpg',
#  'CA_0711.jpg',
#  'CA_0036.jpg',
#  'CA_0106.jpg',
#  'CA_0668.jpg',
#  'CA_0816.jpg',
#  'CA_0717.jpg',
#  'CA_1047.jpg',
#  'CA_0363.jpg',
#  'CA_0633.jpg',
#  'CA_0870.jpg',
#  'CA_0857.jpg',
#  'CA_0559.jpg',
#  'CA_0324.jpg',
#  'CA_0845.jpg',
#  'CA_0891.jpg',
#  'CA_0918.jpg',
#  'CA_0699.jpg',
#  'CA_0893.jpg',
#  'CA_0055.jpg',
#  'CA_0075.jpg',
#  'CA_0227.jpg',
#  'CA_0533.jpg',
#  'CA_0513.jpg',
#  'CA_0200.jpg',
#  'CA_0709.jpg',
#  'CA_0285.jpg',
#  'CA_0255.jpg',
#  'CA_0567.jpg',
#  'CA_0351.jpg',
#  'CA_0359.jpg',
#  'CA_0486.jpg',
#  'CA_0481.jpg',
#  'CA_0555.jpg',
#  'CA_0873.jpg',
#  'CA_0720.jpg',
#  'CA_0391.jpg',
#  'CA_0562.jpg',
#  'CA_0511.jpg',
#  'CA_1070.jpg',
#  'CA_0032.jpg',
#  'CA_0895.jpg',
#  'CA_0112.jpg',
#  'CA_0357.jpg',
#  'CA_0287.jpg',
#  'CA_0656.jpg',
#  'CA_0396.jpg',
#  'CA_0502.jpg',
#  'CA_0635.jpg',
#  'CA_0756.jpg',
#  'CA_0197.jpg',
#  'CA_0375.jpg',
#  'CA_0040.jpg',
#  'CA_0201.jpg',
# ...

# %%
import shutil

source_folder = "Data/"
destination_folder = "CA/"
files_to_move = prefixed

# iterate files
for file in files_to_move:
    # construct full file path
    source = source_folder + file
    destination = destination_folder + file
    # move file
    shutil.move(source, destination)
    print('Moved:', file)
# Out:
# Moved: CA_0672.jpg
# Moved: CA_0784.jpg
# Moved: CA_0711.jpg
# Moved: CA_0036.jpg
# Moved: CA_0106.jpg
# Moved: CA_0668.jpg
# Moved: CA_0816.jpg
# Moved: CA_0717.jpg
# Moved: CA_1047.jpg
# Moved: CA_0363.jpg
# Moved: CA_0633.jpg
# Moved: CA_0870.jpg
# Moved: CA_0857.jpg
# Moved: CA_0559.jpg
# Moved: CA_0324.jpg
# Moved: CA_0845.jpg
# Moved: CA_0891.jpg
# Moved: CA_0918.jpg
# Moved: CA_0699.jpg
# Moved: CA_0893.jpg
# Moved: CA_0055.jpg
# Moved: CA_0075.jpg
# Moved: CA_0227.jpg
# Moved: CA_0533.jpg
# Moved: CA_0513.jpg
# Moved: CA_0200.jpg
# Moved: CA_0709.jpg
# Moved: CA_0285.jpg
# Moved: CA_0255.jpg
# Moved: CA_0567.jpg
# Moved: CA_0351.jpg
# Moved: CA_0359.jpg
# Moved: CA_0486.jpg
# Moved: CA_0481.jpg
# Moved: CA_0555.jpg
# Moved: CA_0873.jpg
# Moved: CA_0720.jpg
# Moved: CA_0391.jpg
# Moved: CA_0562.jpg
# Moved: CA_0511.jpg
# Moved: CA_1070.jpg
# Moved: CA_0032.jpg
# Moved: CA_0895.jpg
# Moved: CA_0112.jpg
# Moved: CA_0357.jpg
# Moved: CA_0287.jpg
# Moved: CA_0656.jpg
# ...

# %%
prefixed = [filename for filename in os.listdir('Data') if filename.startswith("MN_")]

source_folder = "Data/"
destination_folder = "MN/"
files_to_move = prefixed

# iterate files
for file in files_to_move:
    # construct full file path
    source = source_folder + file
    destination = destination_folder + file
    # move file
    shutil.move(source, destination)
    print('Moved:', file)
# Out:
# Moved: MN_0793.jpg
# Moved: MN_1340.jpg
# Moved: MN_0496.jpg
# Moved: MN_0252.jpg
# Moved: MN_1366.jpg
# Moved: MN_0294.jpg
# Moved: MN_1127.jpg
# Moved: MN_0117.jpg
# Moved: MN_1077.jpg
# Moved: MN_0914.jpg
# Moved: MN_0904.jpg
# Moved: MN_0010.jpg
# Moved: MN_1470.jpg
# Moved: MN_0979.jpg
# Moved: MN_1019.jpg
# Moved: MN_0676.jpg
# Moved: MN_0388.jpg
# Moved: MN_0266.jpg
# Moved: MN_0969.jpg
# Moved: MN_0208.jpg
# Moved: MN_0512.jpg
# Moved: MN_0119.jpg
# Moved: MN_0025.jpg
# Moved: MN_1336.jpg
# Moved: MN_1266.jpg
# Moved: MN_0256.jpg
# Moved: MN_1034.jpg
# Moved: MN_1421.jpg
# Moved: MN_0227.jpg
# Moved: MN_0503.jpg
# Moved: MN_1436.jpg
# Moved: MN_1440.jpg
# Moved: MN_1390.jpg
# Moved: MN_0865.jpg
# Moved: MN_0454.jpg
# Moved: MN_0220.jpg
# Moved: MN_0702.jpg
# Moved: MN_0806.jpg
# Moved: MN_1091.jpg
# Moved: MN_1406.jpg
# Moved: MN_0324.jpg
# Moved: MN_0922.jpg
# Moved: MN_1298.jpg
# Moved: MN_0425.jpg
# Moved: MN_1360.jpg
# Moved: MN_1565.jpg
# Moved: MN_1343.jpg
# ...

# %%
prefixed = [filename for filename in os.listdir('Data') if filename.startswith("M_")]

source_folder = "Data/"
destination_folder = "M/"
files_to_move = prefixed

# iterate files
for file in files_to_move:
    # construct full file path
    source = source_folder + file
    destination = destination_folder + file
    # move file
    shutil.move(source, destination)
    print('Moved:', file)
# Out:
# Moved: M_0976.jpg
# Moved: M_1059.jpg
# Moved: M_0197.jpg
# Moved: M_0598.jpg
# Moved: M_0929.jpg
# Moved: M_0343.jpg
# Moved: M_0388.jpg
# Moved: M_0768.jpg
# Moved: M_0056.jpg
# Moved: M_0317.jpg
# Moved: M_1057.jpg
# Moved: M_0943.jpg
# Moved: M_0745.jpg
# Moved: M_0153.jpg
# Moved: M_0877.jpg
# Moved: M_0966.jpg
# Moved: M_0013.jpg
# Moved: M_0515.jpg
# Moved: M_1067.jpg
# Moved: M_0118.jpg
# Moved: M_0325.jpg
# Moved: M_0156.jpg
# Moved: M_0939.jpg
# Moved: M_0548.jpg
# Moved: M_0202.jpg
# Moved: M_0360.jpg
# Moved: M_0620.jpg
# Moved: M_0800.jpg
# Moved: M_0132.jpg
# Moved: M_0371.jpg
# Moved: M_0540.jpg
# Moved: M_0004.jpg
# Moved: M_0687.jpg
# Moved: M_1060.jpg
# Moved: M_0662.jpg
# Moved: M_0772.jpg
# Moved: M_0954.jpg
# Moved: M_0018.jpg
# Moved: M_0457.jpg
# Moved: M_0799.jpg
# Moved: M_0738.jpg
# Moved: M_0566.jpg
# Moved: M_0390.jpg
# Moved: M_0375.jpg
# Moved: M_0476.jpg
# Moved: M_0126.jpg
# Moved: M_0844.jpg
# Moved: M_1091.jpg
# Moved: M_1006.jpg
# Moved: M_0297.jpg
# ...

# %%
prefixed = [filename for filename in os.listdir('Data') if filename.startswith("L_")]

source_folder = "Data/"
destination_folder = "L/"
files_to_move = prefixed

# iterate files
for file in files_to_move:
    # construct full file path
    source = source_folder + file
    destination = destination_folder + file
    # move file
    shutil.move(source, destination)
    print('Moved:', file)
# Out:
# Moved: L_0326.jpg
# Moved: L_1196.jpg
# Moved: L_0785.jpg
# Moved: L_0465.jpg
# Moved: L_0899.jpg
# Moved: L_0970.jpg
# Moved: L_0726.jpg
# Moved: L_0558.jpg
# Moved: L_0942.jpg
# Moved: L_0781.jpg
# Moved: L_1119.jpg
# Moved: L_0504.jpg
# Moved: L_1060.jpg
# Moved: L_1002.jpg
# Moved: L_0532.jpg
# Moved: L_1091.jpg
# Moved: L_0361.jpg
# Moved: L_0121.jpg
# Moved: L_0369.jpg
# Moved: L_0697.jpg
# Moved: L_1225.jpg
# Moved: L_0674.jpg
# Moved: L_0940.jpg
# Moved: L_1136.jpg
# Moved: L_0070.jpg
# Moved: L_0343.jpg
# Moved: L_0905.jpg
# Moved: L_0406.jpg
# Moved: L_1161.jpg
# Moved: L_1067.jpg
# Moved: L_0410.jpg
# Moved: L_0511.jpg
# Moved: L_1116.jpg
# Moved: L_0358.jpg
# Moved: L_0872.jpg
# Moved: L_0956.jpg
# Moved: L_0752.jpg
# Moved: L_0777.jpg
# Moved: L_0341.jpg
# Moved: L_1075.jpg
# Moved: L_1048.jpg
# Moved: L_0301.jpg
# Moved: L_0200.jpg
# Moved: L_1025.jpg
# Moved: L_0506.jpg
# Moved: L_1122.jpg
# Moved: L_1011.jpg
# Moved: L_0434.jpg
# Moved: L_0750.jpg
# Moved: L_0806.jpg
# ...

# %%
prefixed = [filename for filename in os.listdir('Data') if filename.startswith("KA_")]

source_folder = "Data/"
destination_folder = "KA/"
files_to_move = prefixed

# iterate files
for file in files_to_move:
    # construct full file path
    source = source_folder + file
    destination = destination_folder + file
    # move file
    shutil.move(source, destination)
    print('Moved:', file)
# Out:
# Moved: KA_1210.jpg
# Moved: KA_1185.jpg
# Moved: KA_0106.jpg
# Moved: KA_0319.jpg
# Moved: KA_1530.jpg
# Moved: KA_1294.jpg
# Moved: KA_0069.jpg
# Moved: KA_1355.jpg
# Moved: KA_0258.jpg
# Moved: KA_0881.jpg
# Moved: KA_0009.jpg
# Moved: KA_0304.jpg
# Moved: KA_0323.jpg
# Moved: KA_1196.jpg
# Moved: KA_0689.jpg
# Moved: KA_0814.jpg
# Moved: KA_1503.jpg
# Moved: KA_0173.jpg
# Moved: KA_0669.jpg
# Moved: KA_0262.jpg
# Moved: KA_0972.jpg
# Moved: KA_0903.jpg
# Moved: KA_0430.jpg
# Moved: KA_0620.jpg
# Moved: KA_0946.jpg
# Moved: KA_1498.jpg
# Moved: KA_0571.jpg
# Moved: KA_1098.jpg
# Moved: KA_0865.jpg
# Moved: KA_1070.jpg
# Moved: KA_0735.jpg
# Moved: KA_0991.jpg
# Moved: KA_0379.jpg
# Moved: KA_0514.jpg
# Moved: KA_0610.jpg
# Moved: KA_0910.jpg
# Moved: KA_0005.jpg
# Moved: KA_1479.jpg
# Moved: KA_0546.jpg
# Moved: KA_0971.jpg
# Moved: KA_0474.jpg
# Moved: KA_0516.jpg
# Moved: KA_0586.jpg
# Moved: KA_0255.jpg
# Moved: KA_0207.jpg
# Moved: KA_1387.jpg
# Moved: KA_1114.jpg
# ...

# %%
prefixed = [filename for filename in os.listdir('Data') if filename.startswith("KB_")]

source_folder = "Data/"
destination_folder = "KB/"
files_to_move = prefixed

# iterate files
for file in files_to_move:
    # construct full file path
    source = source_folder + file
    destination = destination_folder + file
    # move file
    shutil.move(source, destination)
    print('Moved:', file)
# Out:
# Moved: KB_1084.jpg
# Moved: KB_0656.jpg
# Moved: KB_0643.jpg
# Moved: KB_0665.jpg
# Moved: KB_0194.jpg
# Moved: KB_0540.jpg
# Moved: KB_1011.jpg
# Moved: KB_0515.jpg
# Moved: KB_0567.jpg
# Moved: KB_0842.jpg
# Moved: KB_0880.jpg
# Moved: KB_0183.jpg
# Moved: KB_1001.jpg
# Moved: KB_1109.jpg
# Moved: KB_0148.jpg
# Moved: KB_0618.jpg
# Moved: KB_0283.jpg
# Moved: KB_0489.jpg
# Moved: KB_0431.jpg
# Moved: KB_0129.jpg
# Moved: KB_0602.jpg
# Moved: KB_0764.jpg
# Moved: KB_0060.jpg
# Moved: KB_0632.jpg
# Moved: KB_0938.jpg
# Moved: KB_1068.jpg
# Moved: KB_0502.jpg
# Moved: KB_0005.jpg
# Moved: KB_0007.jpg
# Moved: KB_0336.jpg
# Moved: KB_0242.jpg
# Moved: KB_0970.jpg
# Moved: KB_0553.jpg
# Moved: KB_0400.jpg
# Moved: KB_0197.jpg
# Moved: KB_0687.jpg
# Moved: KB_1131.jpg
# Moved: KB_0321.jpg
# Moved: KB_0104.jpg
# Moved: KB_0151.jpg
# Moved: KB_0097.jpg
# Moved: KB_0360.jpg
# Moved: KB_0824.jpg
# Moved: KB_0458.jpg
# Moved: KB_0625.jpg
# Moved: KB_0840.jpg
# Moved: KB_0392.jpg
# ...

# %%
prefixed = [filename for filename in os.listdir('Data') if filename.startswith("DTDT_")]

source_folder = "Data/"
destination_folder = "DT/"
files_to_move = prefixed

# iterate files
for file in files_to_move:
    # construct full file path
    source = source_folder + file
    destination = destination_folder + file
    # move file
    shutil.move(source, destination)
    print('Moved:', file)

# %%
pip install gradio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 3.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 3.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 3.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 kB 3.1 MB/s eta 0:00:00a 0:00:01
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
import gradio as gr

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

data_dir = 'Data'
data_dir = pathlib.Path(data_dir)

# %%
ten = list(data_dir.glob('Melanocytic Nevus/*'))
print(ten[0])
PIL.Image.open(str(ten[0]))
# Out:
# Data/Melanocytic Nevus/MN_0793.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450>

# %%
img_height,img_width=180,180
batch_size=32
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 9012 files belonging to 7 classes.
# Using 7210 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 9012 files belonging to 7 classes.
# Using 1802 files for validation.

# %%
class_name = train_ds.class_names
class_names = class_name[1:]
print(class_names)
# Out:
# ['Dermatofibroma', 'Keratosis (Actinic)', 'Keratosis (Benign)', 'Melanocytic Nevus', 'Melanoma', 'Skin Lesion']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(6):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 8
#       6 ax = plt.subplot(3, 3, i + 1)
#       7 plt.imshow(images[i].numpy().astype("uint8"))
# ----> 8 plt.title(class_names[labels[i]])
#       9 plt.axis("off")
#
# IndexError: list index out of range

# %%
num_classes = 7

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes,activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=5
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/5
# 226/226 [==============================] - 69s 299ms/step - loss: 1.8941 - accuracy: 0.2144 - val_loss: 1.9402 - val_accuracy: 0.1853
# Epoch 2/5
# 124/226 [===============>..............] - ETA: 25s - loss: 1.8535 - accuracy: 0.2210

# %%
def predict_image(img):
  img_4d=img.reshape(-1,180,180,3)
  prediction=model.predict(img_4d)[0]
  return {class_names[i]: float(prediction[i]) for i in range(7)}

# %%
image = gr.inputs.Image(shape=(180,180))
label = gr.outputs.Label(num_top_classes=7)

gr.Interface(fn=predict_image, inputs=image, outputs=label,interpretation='default').launch(share='True')
